# %%
import pyodbc 
from os import getcwd
import nltk

DRIVER_NAME = "Microsoft Access Driver (*.mdb, *.accdb)"
# Ruta completa del archivo.
#DB_PATH = getcwd() + "/Revisiones_literatura-DESKTOP-92GM44S.accdb"
DB_PATH="C:\\Users\\HP\\OneDrive\\Investigaciones\\Doctorado\\Revision sistemática\\Revision usando star office\\Revisiones_literatura-DESKTOP-92GM44S.accdb" 
# Establecer la conexión.
conn = pyodbc.connect("Driver={%s};DBQ=%s;" % (DRIVER_NAME, DB_PATH))


SQL_Query="SELECT id,Observaciones,titulo from Articulo"
cursor = conn.cursor()
cursor.execute(SQL_Query)
rows = cursor.fetchall()

if rows is not None:
    for row in rows:
        text = row.titulo 
        print('\n')       
        if text is not None: 
            textTokenizer = nltk.Text(nltk.word_tokenize(text,'Spanish'))
            print(row.id,row.titulo)

            match = textTokenizer.concordance('framework')                        
      

cursor.close()
conn.close()
# Out:
# 5 Deep learning in hospitality and tourism: a research framework agenda for future research
# Displaying 1 of 1 matches:
# spitality and tourism : a research framework agenda for future research
#
#
# 6 An integrated framework of behavioral reasoning theory, theory of planned behavior, moral norm and emotions for fostering hospitality/tourism employees’ sustainable behaviors
# Displaying 1 of 1 matches:
# An integrated framework of behavioral reasoning theory , t
#
#
# 8 Malaysia smart tourism framework: Is smart mobility relevant?
# Displaying 1 of 1 matches:
# Malaysia smart tourism framework : Is smart mobility relevant ?
#
#
# 9 Visitor’s Motivational Framework and Wine Routes’
# Contribution to Sustainable Agriculture and Tourism
# Displaying 1 of 1 matches:
# Visitor ’ s Motivational Framework and Wine Routes ’ Contribution to
#
#
# 10 Business, Management and Accounting: Tourism, Leisure and Hospitality Management
# no matches
#
#
# 11 What configurational conditions promote tourism eco-transformation? a fuzzy-set qualitative comparative analysis based on the TOE framework
# Displaying 1 of 1 matches:
# parative analysis based on the TOE framework
#
#
# 12  Novel Framework for Exploring the Spatial Characteristics of Leisure Tourism Using Multisource Data: A Case Study of Qingdao, China
# Displaying 1 of 1 matches:
# Novel Framework for Exploring the Spatial Characte
#
#
# 13 SLOW TRAVEL IN TOURISM - AN OUTLINE OF CONCEPTUAL FRAMEWORKS: POTENTIAL AND LIMITS IN THE CONTEXT OF POST-PANDEMIC RECOVERY
# no matches
#
#
# 14 Conference tourism competitiveness: An applied AHP framework
# Displaying 1 of 1 matches:
# m competitiveness : An applied AHP framework
#
#
# 15 Facing the era of smartness: constructing a framework of required technology competencies for hospitality practitioners
# Displaying 1 of 1 matches:
#  era of smartness : constructing a framework of required technology competencie
#
#
# 16 A FUZZY MULTI-CRITERIA FRAMEWORK FOR THE DEVELOPMENT OF SUSTAINABLE COMMUNITY-BASED TOURISM IN MALAYSIA
# Displaying 1 of 1 matches:
# A FUZZY MULTI-CRITERIA FRAMEWORK FOR THE DEVELOPMENT OF SUSTAINABLE
#
#
# 17 A multi-layer organizational culture framework for enhancing the financial performance in tourism and hospitality family firms
# Displaying 1 of 1 matches:
# multi-layer organizational culture framework for enhancing the financial perfor
#
#
# 19 Tourism e-commerce live streaming: Identifying and testing a value-based marketing framework from the live streamer perspective
# Displaying 1 of 1 matches:
# nd testing a value-based marketing framework from the live streamer perspective
#
#
# 20 A framework to identify destination vulnerability to hazards
# Displaying 1 of 1 matches:
# A framework to identify destination vulnerabil
#
#
# 21 Proposal for a Framework to Develop Sustainable Tourism on the Santurbán Moor, Colombia, as an Alternative Source of Income between Environmental Sustainability and Minin
# Displaying 1 of 1 matches:
# Proposal for a Framework to Develop Sustainable Tourism on
#
#
# 22 A socio-technical approach to the assessment of sustainable tourism: Adding value with a comprehensive process-oriented framework
# Displaying 1 of 1 matches:
# h a comprehensive process-oriented framework
#
#
# 23 A GIS representation framework for location-based social media activities
# Displaying 1 of 1 matches:
# A GIS representation framework for location-based social media ac
#
#
# 24 Legal aspects of ecotourism: towards creating an international legislative framework
# Displaying 1 of 1 matches:
# ating an international legislative framework
#
#
# 26 Commentary: general principles and analytical frameworks in geography and GIScience
# no matches
#
#
# 27 Towards a holistic framework for delivering quality GIS education within and across
# Displaying 1 of 1 matches:
# Towards a holistic framework for delivering quality GIS educati
#
#
# 28 Assessment of intersection conflicts between riders and pedestrians using a GIS-based framework and portable LiDAR
# Displaying 1 of 1 matches:
#  and pedestrians using a GIS-based framework and portable LiDAR
#
#
# 29 The RV camping framework for understanding modern camping practices
# Displaying 1 of 1 matches:
# The RV camping framework for understanding modern camping p
#
#
# 30 The action logic and interpretation framework of residents’ resistance in rural tourism development
# Displaying 1 of 1 matches:
# he action logic and interpretation framework of residents ’ resistance in rural
#
#
# 31 PyCLKDE: A big data-enabled high-performance computational framework for species habitat suitability modeling and mappingPyCLKDE: A big data-enabled high-performance computational framework for species habitat suitability modeling and mapping
# Displaying 2 of 2 matches:
# led high-performance computational framework for species habitat suitability mo
# led high-performance computational framework for species habitat suitability mo
#
#
# 32 The development of sustainable livelihood framework for community-based ecotourism in developing countries
# Displaying 1 of 1 matches:
# elopment of sustainable livelihood framework for community-based ecotourism in
#
#
# 36 System Dynamics framework for tourism development management
# Displaying 1 of 1 matches:
# System Dynamics framework for tourism development management
#
#
# 37 An IAD type framework for Blockchain enabled smart tourism ecosystem
# Displaying 1 of 1 matches:
# An IAD type framework for Blockchain enabled smart touri
#
#
# 38 FESRCT: A Framework for the Event Semantic Retrieval of Cultural Tourism
# Displaying 1 of 1 matches:
# FESRCT : A Framework for the Event Semantic Retrieval o
#
#
# 39 Hybrid recommender system for tourism based on big data and AI: A conceptual framework
# Displaying 1 of 1 matches:
#  on big data and AI : A conceptual framework
#
#
# 40 Internet of Medical Things (IoMT) Based Framework for Smart Healthcare Tourism Sector.
# Displaying 1 of 1 matches:
# t of Medical Things ( IoMT ) Based Framework for Smart Healthcare Tourism Secto
#
#
# 41 Narcotourism: a conceptual framework and research agenda
# Displaying 1 of 1 matches:
# Narcotourism : a conceptual framework and research agenda
#
#
# 42 Towards a conceptual framework for diaspora tourism
# Displaying 1 of 1 matches:
# Towards a conceptual framework for diaspora tourism
#
#
# 43 Framework for creating sustainable tourism using systems thinking
# Displaying 1 of 1 matches:
#  Framework for creating sustainable tourism u
#
#
# 44 Tourism slogans – Towards a conceptual framework
# Displaying 1 of 1 matches:
# ism slogans – Towards a conceptual framework
#
#
# 45 A framework for connecting two interoperability universes: OGC Web Feature Services and Linked Data
# Displaying 1 of 1 matches:
# A framework for connecting two interoperabilit
#
#
# 46 A sustainable medical tourism framework based on the enterprise architecture design: The case in Thailand
# Displaying 1 of 1 matches:
# A sustainable medical tourism framework based on the enterprise architectu
#
#
# 47 GIS-based seamless tide prediction framework in the Persian Gulf
# Displaying 1 of 1 matches:
# GIS-based seamless tide prediction framework in the Persian Gulf
#
#
# 48 A new framework for accessible tourism mobile application development
# Displaying 1 of 1 matches:
# A new framework for accessible tourism mobile appl
#
#
# 49 Creating a conceptual framework to improve the re-usability of open geographic data in cities
# Displaying 1 of 1 matches:
# Creating a conceptual framework to improve the re-usability of ope
#
#
# 50 An IT Governance Framework for Virtual Enterprise in Tourism Industry: Evidence from Small Tourism Enterprises in Thailand
# Displaying 1 of 1 matches:
# An IT Governance Framework for Virtual Enterprise in Tourism
#
#
# 51 Familiar tourists, their behaviours and place attachments: an empirical framework
# Displaying 1 of 1 matches:
# d place attachments : an empirical framework
#
#
# 52 An enabling Framework for Blockchain in Tourism
# Displaying 1 of 1 matches:
# An enabling Framework for Blockchain in Tourism
#
#
# 53 Blockchain technology framework: Current and future perspectives for the tourism industry
# Displaying 1 of 1 matches:
# Blockchain technology framework : Current and future perspectives
#
#
# 54 Bridging worlds: Utilizing a multi-stakeholder framework to create extension-tourism partnerships
# Displaying 1 of 1 matches:
# ds : Utilizing a multi-stakeholder framework to create extension-tourism partne
#
#
# 55 Community-based tourism in developing countries: A framework for policy evaluation
# Displaying 1 of 1 matches:
# ourism in developing countries : A framework for policy evaluation
#
#
# 56 Comparison of built-up area maps produced within the global human settlement framework
# Displaying 1 of 1 matches:
# within the global human settlement framework
#
#
# 57 Developing an indicator framework for assessing sustainable tourism: Evidence from a Taiwan ecological resort
# Displaying 1 of 1 matches:
# Developing an indicator framework for assessing sustainable tourism
#
#
# 58 Developing an indicator-based framework to measure sustainable tourism in romania. A territorial approach
# Displaying 1 of 1 matches:
# Developing an indicator-based framework to measure sustainable tourism in
#
#
# 59 Digital Tourism and Wellbeing: Conceptual Framework to Examine Technology Effects of Online Travel Media
# Displaying 1 of 1 matches:
# Tourism and Wellbeing : Conceptual Framework to Examine Technology Effects of O
#
#
# 60 Entrepreneurship development framework for smallscale rural tourism establishments in South Africa
# Displaying 1 of 1 matches:
# Entrepreneurship development framework for smallscale rural tourism estab
#
#
# 61 E-tourism: Definition, development and conceptual framework
# Displaying 1 of 1 matches:
# ition , development and conceptual framework
#
#
# 62 International frameworks promoting tourism for poverty alleviation and sustainable development
# no matches
#
#
# 63 A proposed framework for measuring the effectiveness of social media: A study of irish tourism
# Displaying 1 of 1 matches:
# A proposed framework for measuring the effectiveness of
#
#
# 64 A Suite of System Dynamics T&L Simulations and Games Based Upon the Australian Qualifications Framework (AQF)
# Displaying 1 of 1 matches:
# Upon the Australian Qualifications Framework ( AQF )
#
#
# 65 Tidal tourism flow study: Conceptual framework and research ideas
# Displaying 1 of 1 matches:
# al tourism flow study : Conceptual framework and research ideas
#
#
# 66 Mathematical vector framework for gravity-specific land surface curvatures calculation from triangulated irregular network
# Displaying 1 of 1 matches:
# Mathematical vector framework for gravity-specific land surface
#
#
# 67 Social media for outbound leisure travel: a framework based on technology acceptance model (TAM)
# Displaying 1 of 1 matches:
# ia for outbound leisure travel : a framework based on technology acceptance mod
#
#
# 68 Tourism systems thinking: Towards an integrated framework to guide the study of the tourism phenomenon
# Displaying 1 of 1 matches:
# s thinking : Towards an integrated framework to guide the study of the tourism
#
#
# 69 Methodological framework for producing national tourism statistics from mobile positioning data
# Displaying 1 of 1 matches:
# Methodological framework for producing national tourism sta
#
#
# 70 An application of the sports logistics framework: the case of the Dallas Cowboys
# Displaying 1 of 1 matches:
# pplication of the sports logistics framework : the case of the Dallas Cowboys
#
#
# 71 A Spatial Improved-kNN-Based Flood Inundation Risk Framework for Urban Tourism under Two Rainfall Scenarios
# Displaying 1 of 1 matches:
# ed-kNN-Based Flood Inundation Risk Framework for Urban Tourism under Two Rainfa
#
#
# 72 A TAM Framework to Evaluate the Effect of Smartphone Application on Tourism Information Search Behavior of Foreign Independent Travelers
# Displaying 1 of 1 matches:
# A TAM Framework to Evaluate the Effect of Smartpho
#
#
# 73 A Ticket to Coffee: Stakeholders’ view and Theoretical Framework of Coffee Tourism Benefits
# Displaying 1 of 1 matches:
# takeholders ’ view and Theoretical Framework of Coffee Tourism Benefits
#
#
# 75 Airbnb, Technological Change and Disruption in Barbadian Tourism:a theoretical framework
# Airbnb, technological change and disruption in Barbadian tourism: a theoretical framework
# Displaying 2 of 2 matches:
#  Barbadian Tourism : a theoretical framework Airbnb , technological change and
#  Barbadian tourism : a theoretical framework
#
#
# 76 An Integrated Decision Support Framework Using Single-Valued-MEREC-MULTIMOORA for Low Carbon Tourism Strategy Assessment
# Displaying 1 of 1 matches:
# An Integrated Decision Support Framework Using Single-Valued-MEREC-MULTIMOO
#
#
# 77 A Deep Learning-Based Text Emotional Analysis Framework for Yellow River Basin Tourism Culture
# Displaying 1 of 1 matches:
# ning-Based Text Emotional Analysis Framework for Yellow River Basin Tourism Cul
#
#
# 78 A Conceptual Framework for Value Co-Creation in Service Enterprises (Case of Tourism Agencies)
# Displaying 1 of 1 matches:
# A Conceptual Framework for Value Co-Creation in Service E
#
#
# 79 A Decision-Making and Governance Framework for the Renewal of Tourism Destinations: The Case of the Canary Islands
# Displaying 1 of 1 matches:
# A Decision-Making and Governance Framework for the Renewal of Tourism Destina
#
#
# 80 Young tourists’ experiences at dark tourism sites: Towards a conceptual framework
# Displaying 1 of 1 matches:
# urism sites : Towards a conceptual framework
#
#
# 81 Validating A Proposed CRM Implementation Framework For The Mauritian Hotel Industry
# Displaying 1 of 1 matches:
# ting A Proposed CRM Implementation Framework For The Mauritian Hotel Industry
#
#
# 82 Understanding museum vacationers’ eco-friendly decision-making process:
# Understanding museum vacationers' eco-friendly decision-making process: strengthening the VBN framework
# Displaying 1 of 1 matches:
# ng process : strengthening the VBN framework
#
#
# 83 Understanding Mobile Tourism Shopping in Pakistan: An Integrating Framework of Innovation Diffusion Theory and Technology Acceptance Model
# Displaying 1 of 1 matches:
# pping in Pakistan : An Integrating Framework of Innovation Diffusion Theory and
#
#
# 84 Understanding consumer switching intention of peer-to-peer accommodation: A push-pull-mooring framework
# Displaying 1 of 1 matches:
# ccommodation : A push-pull-mooring framework
#
#
# 85 Towards advancing theory and methods on tourism development from residents’ perspectives: Developing a framework on the pathway to impact
# Displaying 1 of 1 matches:
# ents ’ perspectives : Developing a framework on the pathway to impact
#
#
# 86 Towards a post-conflict tourism recovery framework
# Displaying 1 of 1 matches:
# s a post-conflict tourism recovery framework
#
#
# 87 Towards a framework for disaster risk reduction in indonesia’s Urban tourism industry based on spatial information
# Displaying 1 of 1 matches:
# Towards a framework for disaster risk reduction in ind
#
#
# 88 Toward a co-Creation framework for developing a green sports event brand: the case of the 2018 Zürich E Prix
# Displaying 1 of 1 matches:
# Toward a co-Creation framework for developing a green sports even
#
#
# 89 Tourism, Empowerment and Sustainable Development: A New Framework for Analysis
# Displaying 1 of 1 matches:
# nd Sustainable Development : A New Framework for Analysis
#
#
# 90 Tourism and Inclusive Growth: Evaluating a Diagnostic Framework
# Displaying 1 of 1 matches:
# e Growth : Evaluating a Diagnostic Framework
#
#
# 91 The Role of Tourism in the Ecosystem Services Framework
# Displaying 1 of 1 matches:
#  Tourism in the Ecosystem Services Framework
#
#
# 92 The Influence of Smart Technologies on Customer Journey in Tourist Attractions within the Smart Tourism Management Framework
# Displaying 1 of 1 matches:
# ithin the Smart Tourism Management Framework
#
#
# 93 The evaluation of tourism service facilities in Chinese traditional villages based on the living protection concept: theoretical framework and empirical case study
# Displaying 1 of 1 matches:
# g protection concept : theoretical framework and empirical case study
#
#
# 94 The competitive productivity (CP) of tourism destinations: an integrative conceptual framework and a reflection on big data and analytics
# Displaying 1 of 1 matches:
# ations : an integrative conceptual framework and a reflection on big data and a
#
#
# 95 Sustainable Tourism as a Driving Force in Regional Development of Remote Regions in Siberia: An Integrated Operational Framework
# Displaying 1 of 1 matches:
# iberia : An Integrated Operational Framework
#
#
# 99 Sustainability: A thematic synthesis of globally published ecotourism frameworks
# no matches
#
#
# 100 Risk Types and Coping Mechanisms for Ethical Tourism Entrepreneurs: A New Conceptual Framework
# Displaying 1 of 1 matches:
# m Entrepreneurs : A New Conceptual Framework
#
#
# 101 Risk reduction and adventure tourism safety: An extension of the risk perception attitude framework (RPAF)
# Displaying 1 of 1 matches:
# on of the risk perception attitude framework ( RPAF )
#
#
# 102 Reviving tourism industry post-COVID-19: A resilience-based framework
# Displaying 1 of 1 matches:
# post-COVID-19 : A resilience-based framework
#
#
# 103 Restoration of visitors through nature-based tourism: A systematic review, conceptual framework, and future research directions
# Displaying 1 of 1 matches:
# : A systematic review , conceptual framework , and future research directions
#
#
# 104 Post-COVID-19 recovery of island tourism using a smart tourism destination framework
# Displaying 1 of 1 matches:
#  using a smart tourism destination framework
#
#
# 105 Post-conflict tourism opportunity spectrum (POCTOS): a framework for destinations recovering from conflict
# Displaying 1 of 1 matches:
# pportunity spectrum ( POCTOS ) : a framework for destinations recovering from c
#
#
# 106 Place-Related Concepts and Pro-Environmental Behavior in Tourism Research: A Conceptual Framework
# Displaying 1 of 1 matches:
# in Tourism Research : A Conceptual Framework
#
#
# 107 Islandscapes and sustainable creative tourism: A conceptual framework and guidelines for best practices
# Framework and Guidelines for Best Practices
# Islandscapes and Sustainable Creative Tourism: A Conceptual
# Framework and Guidelines for Best Practices
# Displaying 3 of 3 matches:
# le creative tourism : A conceptual framework and guidelines for best practices
#  and guidelines for best practices Framework and Guidelines for Best Practices
# le Creative Tourism : A Conceptual Framework and Guidelines for Best Practices
#
#
# 108 Implementing social customer relationship management: A process framework and implications in tourism and hospitality
# Displaying 1 of 1 matches:
# elationship management : A process framework and implications in tourism and ho
#
#
# 109 Impacts of Second Home and Visiting Friends and Relatives Tourism on Migration: A Conceptual Framework
# Displaying 1 of 1 matches:
# ourism on Migration : A Conceptual Framework
#
#
# 110 Impact of tourism development upon environmental sustainability: a suggested framework for sustainable ecotourism
# Displaying 1 of 1 matches:
# ental sustainability : a suggested framework for sustainable ecotourism
#
#
# 111 Hamlet Live: the 7 I’s Experiential Strategy Framework for heritage visitor attractions
# Displaying 1 of 1 matches:
#  the 7 I ’ s Experiential Strategy Framework for heritage visitor attractions
#
#
# 112 Framework for Sustainable Recovery of Tourism in Protected Areas
# Displaying 1 of 1 matches:
#  Framework for Sustainable Recovery of Touris
#
#
# 113 Exploring New Vista of Intelligent Recommendation Framework for Tourism Industries: An Itinerary through Big Data Paradigm
# Displaying 1 of 1 matches:
# ista of Intelligent Recommendation Framework for Tourism Industries : An Itiner
#
#
# 114 Establishing a Sustainable Sports Tourism Evaluation Framework with a Hybrid Multi-Criteria Decision-Making Model to Explore Potential Sports Tourism Attractions in Taiwan
# Displaying 1 of 1 matches:
# tainable Sports Tourism Evaluation Framework with a Hybrid Multi-Criteria Decis
#
#
# 115 Enhancing the Tourism Operation Success in Sabah Malaysia: a Conceptual Framework
# Displaying 1 of 1 matches:
# s in Sabah Malaysia : a Conceptual Framework
#
#
# 116 Developing a new framework for conceptualizing the emerging sustainable community-based tourism using an extended interval-valued Pythagorean fuzzy SWARA-MULTIMOORA
# Displaying 1 of 1 matches:
# Developing a new framework for conceptualizing the emerging s
#
#
# 117 A revised sustainable livelihood framework for community-based tourism projects in developing countries
# Displaying 1 of 1 matches:
# A revised sustainable livelihood framework for community-based tourism projec
#
#
# 118 Towards a Tourism and Community-Development
# Framework: An African Perspective
# Displaying 1 of 1 matches:
#  Tourism and Community-Development Framework : An African Perspective
#
#
# 119 Conceptual framework of rural landscape character assessment to guide tourism development in rural areas
# Displaying 1 of 1 matches:
# Conceptual framework of rural landscape character asses
#
#
# 120 A framework for incorporating landscape management into the human-environment relationship research of rural tourism
# Displaying 1 of 1 matches:
# A framework for incorporating landscape manage
#
#
# 121 A benefit segmentation framework for a nature-based tourism destination: the case of Kruger, Panorama and Lowveld areas in Mpumalanga Province
# Displaying 1 of 1 matches:
# A benefit segmentation framework for a nature-based tourism destina
#
#
# 122 Supporting forest conservation through community-based land use planning and participatory GIS – lessons from Crocker Range Park, Malaysian Borneo
# no matches
#
#
# 123 A POLICY FRAMEWORK FOR SUSTAINABLE TOURISM DEVELOPMENT BASED ON PARTICIPATORY APPROACHES: A CASE STUDY IN THE KEDUNG OMBO TOURISM AREA-INDONESIA
# Displaying 1 of 1 matches:
# A POLICY FRAMEWORK FOR SUSTAINABLE TOURISM DEVELOPMEN
#
#
# 124 A pedagogical framework for the development of the critical tourism citizen
# Displaying 1 of 1 matches:
# A pedagogical framework for the development of the critica
#
#
# 125 A novel ontology framework supporting model-based tourism recommender
# Displaying 1 of 1 matches:
# A novel ontology framework supporting model-based tourism rec
#
#
# 126 A novel semantic recognition framework of urban functional zones supporting urban land structure analytics based on open-source data
# Displaying 1 of 1 matches:
# A novel semantic recognition framework of urban functional zones supporti
#
#
# 127 Choice experiment selection of tourism destinations in a dual process theory framework: The role of decision style and potential to promote deliberation
# Displaying 1 of 1 matches:
# tinations in a dual process theory framework : The role of decision style and p
#
#
# 128 Developing a framework of corporate governance best practice for the Malaysian tourism small and medium-sized enterprises
# Displaying 1 of 1 matches:
# Developing a framework of corporate governance best pract
#
#
# 130 when artificial intelligence meets the hospitality and tourism industry: an assessment framework to inform theory and management
# Displaying 1 of 1 matches:
# d tourism industry : an assessment framework to inform theory and management
#
#
# 131 A novel big data mining framework for reconstructing large-scale daily MAIAC AOD data across China from 2000 to 2020
# Displaying 1 of 1 matches:
# A novel big data mining framework for reconstructing large-scale dai
#
#
# 132 A new spatial database framework for pedestrian indoor navigation based on the OpenStreetMap tag information
# Displaying 1 of 1 matches:
# A new spatial database framework for pedestrian indoor navigation b
#
#
# 133 A multi-objective framework for analysis of road network vulnerability for relief facility location during flood hazards: A case study of relief location analysis in Bankura District, India
# Displaying 1 of 1 matches:
# A multi-objective framework for analysis of road network vulne
#
#
# 134 A privacy-preserving framework for location recommendation using decentralized collaborative machine learning
# Displaying 1 of 1 matches:
# A privacy-preserving framework for location recommendation using
#
#
# 135 A strategic framework for analysing employability skills deficits in rural hospitality and tourism destinations
# Displaying 1 of 1 matches:
# A strategic framework for analysing employability skills
#
#
# 136 A sustainability strategy assessment framework model for medical tourism supply chain in Asia
# Displaying 1 of 1 matches:
# sustainability strategy assessment framework model for medical tourism supply c
#
#
# 137 	A dimensional framework of tourism indicators influencing destination competitiveness
# Displaying 1 of 1 matches:
# A dimensional framework of tourism indicators influencing
#
#
# 138 Structuring challenges of sustainable tourism development in protected natural areas with driving force–pressure–state–impact–response (DPSIR) framework
# Displaying 1 of 1 matches:
# re–state–impact–response ( DPSIR ) framework
#
#
# 139 A conceptual framework for indigenous ecotourism projects–a case study in Wayanad, Kerala, India
# Displaying 1 of 1 matches:
# A conceptual framework for indigenous ecotourism projects
#
#
# 140 	A New Framework to Understand Transit Tourism-Related Issues on Pan-European Transport Corridors | [Ein neuer Ansatz zum Verständnis von Fragen des Transittourismus auf gesamteuropäischen Verkehrskorridoren]
# Displaying 1 of 1 matches:
# A New Framework to Understand Transit Tourism-Rela
#
#
# 141 A scenario planning framework for (post-)pandemic tourism in European destinations
# Displaying 1 of 1 matches:
# A scenario planning framework for ( post- ) pandemic tourism in
#
#
# 142 A strategic framework of good governance, infrastructure development and community empowerment in indonesian public sector management
# Displaying 1 of 1 matches:
# A strategic framework of good governance , infrastructur
#
#
# 143 A new holistic conceptual framework for sustainability oriented hospitality innovation with triple bottom line perspective
# Displaying 1 of 1 matches:
# A new holistic conceptual framework for sustainability oriented hospit
#
#
# 144 Designing compelling accommodationscapes: Testing a framework in a rural context
# Displaying 1 of 1 matches:
# ng accommodationscapes : Testing a framework in a rural context
#
#
# 145 A conceptual framework of tourism social entrepreneurship for sustainable community development
# Displaying 1 of 1 matches:
# A conceptual framework of tourism social entrepreneurship
#
#
# 146 A framework for facilitation of community participation in and beneficiation from CBT around the Save Valley Conservancy
# Displaying 1 of 1 matches:
# A framework for facilitation of community part
#
#
# 147 A carbon neutral account framework for the Qomolangma mountaineering tourism area
# Displaying 1 of 1 matches:
# A carbon neutral account framework for the Qomolangma mountaineering
#
#
# 148 A critical framework for interrogating the United Nations Sustainable Development Goals 2030 Agenda in tourism
# Displaying 1 of 1 matches:
# A critical framework for interrogating the United Natio
#
#
# 149 A Framework for Sustainable Tourism Development in and around National Parks
# Displaying 1 of 1 matches:
# A Framework for Sustainable Tourism Developmen
#
#
# 150 From finance to adventure: using ERM as a framework in adventure tourism
# Displaying 1 of 1 matches:
# ance to adventure : using ERM as a framework in adventure tourism
#
#
# 151 Women, Fishermen, and Community-based Tourism at Djoudj Bird National Park, Senegal: an Application Of the Actor–structure Livelihood Framework
# Displaying 1 of 1 matches:
#  Of the Actor–structure Livelihood Framework
#
#
# 152 Kolb’s experiential learning model as a conceptual framework for visual research in rural tourism sites: Batuh narit arur bilit as a case study
# Displaying 1 of 1 matches:
# ial learning model as a conceptual framework for visual research in rural touri
#
#
# 153 A framework for spatial regionalization composed of novel clustering-based algorithms under spatial contiguity constraints
# Displaying 1 of 1 matches:
# A framework for spatial regionalization compos
#
#
# 154 A curriculum framework for undergraduate coastal and marine tourism university programs
# Displaying 1 of 1 matches:
# A curriculum framework for undergraduate coastal and mari
#
#
# 155 A framework for medical tourists' satisfaction and loyalty by costumer segmentation and quality improvement
# Displaying 1 of 1 matches:
# A framework for medical tourists ' satisfactio
#
#
# 156 Evaluación de territorios para desarrollar el turismo comunitario en la región amazónica del Ecuador
# no matches
#
#
# 158 A ‘Reuse Projection Framework’ Based on Othello’s Citadel
# and Cultural Tourism
# Displaying 1 of 1 matches:
# A ‘ Reuse Projection Framework ’ Based on Othello ’ s Citadel and
#
#
# 159 A Conceptual Framework for Identifying the Binding Constraints to Tourism-Driven Inclusive Growth
# Displaying 1 of 1 matches:
# A Conceptual Framework for Identifying the Binding Constr
#
#
# 160 A Conceptual Framework for the Management of a Personal Leadership Brand within the Tourism and Hospitality Industry.
# Displaying 1 of 1 matches:
# A Conceptual Framework for the Management of a Personal L
#
#
# 161 A CulturAl CreAtivity FrAmework For the SuStAinAbility oF intAngible  culturAl heritAge
# Displaying 1 of 1 matches:
# A CulturAl CreAtivity FrAmework For the SuStAinAbility oF intAngib
#
#
# 162 A cultural framework for Māori tourism: values and processes of a Whānau tourism business development
# Displaying 1 of 1 matches:
# A cultural framework for Māori tourism : values and pro
#
#
# 163 A four‐part framework for geodesign software
# creation and research
# Displaying 1 of 1 matches:
# A four‐part framework for geodesign software creation an
#
#
# 164 A framework for social media information flow analytics in cyberspace and physical space
# Displaying 1 of 1 matches:
# A framework for social media information flow
#
#
# 165 A generic space definition framework to support
# seamless indoor/outdoor navigation systems
# Displaying 1 of 1 matches:
# A generic space definition framework to support seamless indoor/outdoor
#
#
# 166 A Framework for Stakeholders’ Involvement in Digital Productions for Cultural Heritage Tourism
# Displaying 1 of 1 matches:
# A Framework for Stakeholders ’ Involvement in
#
#
# 167 Application of the DPSIR framework to assess environmental issues with an emphasis on waste management driven by stationary tourism in Adriatic Croatia
# Displaying 1 of 1 matches:
# Application of the DPSIR framework to assess environmental issues wit
#
#
# 168 Co-management of Capitals for Community Wellbeing and Sustainable Tourism Development: A Conceptual Framework
# Displaying 1 of 1 matches:
# Tourism Development : A Conceptual Framework
#
#
# 170 A social-cognitive framework of small accommodation enterprise sustainability practices
# Displaying 1 of 1 matches:
# A social-cognitive framework of small accommodation enterprise
#
#
# 171 An integrated multi-granular distributed linguistic decision support framework for low-carbon tourism attraction evaluation
# Displaying 1 of 1 matches:
# ibuted linguistic decision support framework for low-carbon tourism attraction
#
#
# 172 Explaining Residents’ Behavioral Support for Tourism through Two Theoretical Frameworks
# no matches
#
#
# 173 Locals' attitudes toward mass and alternative tourism: The case of Sunshine Coast, Australia
# no matches
#
#
# 174 Astrotourism: A literature review and framework for future research
# Displaying 1 of 1 matches:
# otourism : A literature review and framework for future research
#
#
# 175 Revisión Sistemática del Concepto Turismo Comunitario
# no matches
#
#
# 176 System Dynamics framework for tourism development management
# Displaying 1 of 1 matches:
# System Dynamics framework for tourism development management
#
#
# 179 Site suitability evaluation for ecotourism using GIS & AHP: A case study of surat Thani Province, Thailand
# no matches
#
#
# 180 Cultural sustainability – a framework for Aboriginal tourism in British Columbia
# Displaying 1 of 1 matches:
# Cultural sustainability – a framework for Aboriginal tourism in British
#
#
# 181 Nature-based experiential learning as a framework for preparing responsible tourism practitioners
# Displaying 1 of 1 matches:
# e-based experiential learning as a framework for preparing responsible tourism
